# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('random_data.csv')
data.head()
x1 = data.loc[:,"X1"]
x2 = data.loc[:,"X2"]
plt.scatter(x1,x2)
plt.show()

# %%
from scipy.stats import norm
x1_range=np.linspace(0,20,300)
x1_nomal=norm.pdf(x1_range,10,2)

# %%
#visualize the data
import matplotlib.pyplot as plt
import numpy as np

plt.plot(x1_range,x1_nomal)
plt.show()
